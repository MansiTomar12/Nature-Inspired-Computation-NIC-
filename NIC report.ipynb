# %%
#BPP1
# In problem BPP1, b = 10 and the weight of item 𝑖 (where 𝑖 starts at 1 and finishes at 500) will be 𝒊/𝟐.
import numpy as np
import random
#Calculating the fitness of the solution
def calc_fitness(sol):
    d = {}
    for i in range(1,11):
        d[i] = 0
    for index in range(len(sol)):
        d[sol[index]] += (index+1)/2
    return max(d.values()) - min(d.values())

#binary tournament selection - Randomly choose a chromosome from the population; 
def binary_tournament_selection(Population, a,b):
    idx = np.random.randint(a, size=b)
    return Population[idx,:][0]

#Single point crossover -Randomly select a ‘crossover point’ which should be smaller than the total length of the chromosome.
def single_point_crossover(Population):
    a = binary_tournament_selection(Population,10,1)
    b = binary_tournament_selection(Population,10,1) 
    x=np.random.randint(1,500)
    child1=list(a[:x])+list(b[x:])
    child2=list(b[:x])+list(a[x:])
    
    return (child1,child2)

#Multi gene mutation-: You should use the following parameterised mutation operator for this, Mk, where k is an integer
def multi_gene_mutation(child1,child2,k):
    for i in range(k):
        ran=random.randint(1,len(child1))
        val=random.randint(1,10)
        child1[ran-1]=val
        #ran=random.randint(1,len(child1))
        #val=random.randint(1,10)
        child2[ran-1]=val   
    return (child1,child2)
    
#weakest solution replacement -: If the new solution is fitter than the worst in the population, then overwrite theworst with the new solution.
def weakest_solution(child, population, fitness_list):
    c1=calc_fitness(child)
    max_list=[]
    Max_val=max(fitness_list)
    if c1<=Max_val:
        for i in range(len(fitness_list)):
            if fitness_list[i]==Max_val:
                max_list.append(i)
        index = np.random.randint(0, len(max_list), size=1)[0]
        fitness_list[max_list[index]] = c1
        population[max_list[index]] = child

            
    return population, fitness_list

# %%
##All the libraries to be imported for the algorithm including the graph plotating libraries
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
plt.style.use('ggplot')

# %%
#BBP1 experiment 1
#Run five trials of the EA with crossover & operator M1 and population size 10.
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 11, size = (10,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        child1, child2 = single_point_crossover(population)
        child1,child2=multi_gene_mutation(child1,child2,5)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP1 EX1")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#BPP1 experiment 2
#Run five trials of the EA with crossover & operator M1 and population size 100.
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 11, size = (100,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        child1, child2 = single_point_crossover(population)
        child1,child2=multi_gene_mutation(child1,child2,5)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP1 EX2")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for style in plt.style.available:
    print(style)
    plt.style.use(style)
    plt.figure(figsize = (5,3))
    
    

    output_1=(results[0])
    output_2=(results[1])
    output_3=(results[2])
    output_4=(results[3])
    output_5=(results[4])
    plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
    plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
    plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
    plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
    plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
    plt.xlabel("Generations")
    plt.ylabel("Best Fitness")
    plt.title("fitness BPP1 EX2")
    plt.tight_layout()
    plt.legend()
    plt.show()
# Out:
# Solarize_Light2
# _classic_test_patch
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10

# %%
#BPP1 experiment 3
#Run five trials of the EA with crossover & operator M5 and population size 10.
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 11, size = (10,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        child1, child2 = single_point_crossover(population)
        child1,child2=multi_gene_mutation(child1,child2,5)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP1 EX3")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#BPP1 experiment 4
#Run five trials of the EA with crossover & operator M5 and population size 100.
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 11, size = (100,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        child1, child2 = single_point_crossover(population)
        child1,child2=multi_gene_mutation(child1,child2,5)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP1 EX4")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#BPP1 exeperiment 5
#Run five trials of the EA with only operator M5 and population size 10.
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 11, size = (10,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        #child1, child2 = single_point_crossover(population)
        child1,child2=multi_gene_mutation(child1,child2,5)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP1 EX5")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#BPP1 exeperiment 6
#Run five trials of the EA with only crossover M5 and population size 10.
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 11, size = (10,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        child1, child2 = single_point_crossover(population)
        #child1,child2=multi_gene_mutation(child1,child2,5)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP1 EX6")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#BPP2 
#bin = 100 and the weight of item 𝑖 will be 𝒊**𝟐/𝟐
import numpy as np
import random
import pdb
final_fitness=[]
#Calculating the fitness of the solution
def calc_fitness(sol):
    d = {}
    for i in range(1,101):
        d[i] = 0
    for index in range(len(sol)):   
        d[sol[index]] += (index+1)**2/2
    return max(d.values()) - min(d.values())

#binary tournament selection - Randomly choose a chromosome from the population;  
def binary_tournament_selection(Population, a,b):
    idx = np.random.randint(a, size=b)
    return Population[idx,:][0]

#Single point crossover -Randomly select a ‘crossover point’ which should be smaller than the total length of the chromosome. 
def single_point_crossover(Population):
    a = binary_tournament_selection(Population,100,1)
    b = binary_tournament_selection(Population,100,1) 
    x=np.random.randint(1,500)
    child1=list(a[:x])+list(b[x:])
    child2=list(b[:x])+list(a[x:])
    
    return (child1,child2)

#Multi gene mutation-: You should use the following parameterised mutation operator for this, Mk, where k is an integer
def multi_gene_mutation(child1,child2,k):
    for i in range(k):
        ran=random.randint(1,len(child1))
        val=random.randint(1,100)
        child1[ran-1]=val
        #ran=random.randint(1,len(child1))
        #val=random.randint(1,10)
        child2[ran-1]=val   
    return (child1,child2)
    
#weakest solution replacement -: If the new solution is fitter than the worst in the population, then overwrite theworst with the new solution. 
def weakest_solution(child, population, fitness_list):
    c1=calc_fitness(child)
    max_list=[]
    Max_val=max(fitness_list)
    if c1<=Max_val:
        for i in range(len(fitness_list)):
            if fitness_list[i]==Max_val:
                max_list.append(i)
        index = np.random.randint(0, len(max_list), size=1)[0]
        fitness_list[max_list[index]] = c1
        population[max_list[index]] = child

            
    return population, fitness_list

# %%
#All the libraries to be imported for the algorithm including the graph plotating libraries
import pdb
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
plt.style.use('ggplot')

# %%
#BBP2 experiment 1
#Run five trials of the EA with crossover & operator M1 and population size 10.
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 11, size = (100,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        child1, child2 = single_point_crossover(population)
        child1,child2=multi_gene_mutation(child1,child2,5)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP2 EX1")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#BPP2 Experiment 2
#Run five trials of the EA with crossover & operator M1 and population size 100. 
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 101, size = (100,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        child1, child2 = single_point_crossover(population)
        child1,child2=multi_gene_mutation(child1,child2,1)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP2 EX2")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#BPP2 Experiment 3
#Run five trials of the EA with crossover & operator M5 and population size 10.
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 11, size = (100,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        child1, child2 = single_point_crossover(population)
        child1,child2=multi_gene_mutation(child1,child2,5)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP2 EX3")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#BPP2 Experiment 4
#Run five trials of the EA with crossover & operator M5 and population size 100.
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 101, size = (100,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        child1, child2 = single_point_crossover(population)
        child1,child2=multi_gene_mutation(child1,child2,5)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP2 EX4")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#BPP2 Experiment 5
#Run five trials of the EA with only operator M5 and population size 10
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 101, size = (100,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        child1, child2 = single_point_crossover(population)
        child1,child2=multi_gene_mutation(child1,child2,5)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP2 EX5")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#BPP2 Experiment 6
#Run five trials of the EA with only crossover and population size 10. 
import random
np.random.seed(775777)
random.seed(777775)
iteration=0
results=[]
while iteration<5:
    print(iteration)
    population=np.random.randint(1, 101, size = (100,500))
    final_fitness=[]
    counter=0
    fitness_list = []
    graph_val=[]
    for sol in population:
        fitness = calc_fitness(sol)
        fitness_list.append(fitness)
    while counter<10000:
        child1, child2 = single_point_crossover(population)
        #child1,child2=multi_gene_mutation(child1,child2,5)
        population, fitness_list = weakest_solution(child1, population, fitness_list)
        population, fitness_list = weakest_solution(child2, population, fitness_list)
        value=(min(fitness_list))
        counter+=1
        graph_val.append(value)
    results.append(graph_val)
    iteration+=1
#Printing the results with graph
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (6,4))
output_1=(results[0])
output_2=(results[1])
output_3=(results[2])
output_4=(results[3])
output_5=(results[4])
plt.plot(output_1,linewidth=0.3,color='k', label='Trail_1')
plt.plot(output_2,linewidth=0.3, color='y', label='Trail_2')
plt.plot(output_3,linewidth=0.3,color='b',label='Trail_3')
plt.plot(output_4,linewidth=0.3,color='g', label='Trail_4')
plt.plot(output_5,linewidth=0.3,color='m',label='Trail_5')
plt.xlabel("Generations")
plt.ylabel("Best Fitness")
plt.title("fitness BPP2 EX6")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4
